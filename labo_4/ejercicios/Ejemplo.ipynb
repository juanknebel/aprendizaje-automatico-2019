# %% [markdown]
# Caso sintético con forma globulares

# %%
import sklearn.datasets as datasets
import pandas as pandas
from   sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %matplotlib inline
X=pandas.read_csv('./datasets/s4.txt', sep = ';')
X.head()
# Out:
#        x1      x2
# 0  624474  837604
# 1  673412  735362
# 2  647442  677000
# 3  532283  741384
# 4  646529  742844

# %%
x=X['x1']
y=X['x2']

# %%
#Variar k 
n_clusters=4
kmeans = KMeans(n_clusters=n_clusters, max_iter=200)
estimator=kmeans.fit(X)

# %%
c1=estimator.cluster_centers_.transpose()[0].tolist()
c2=estimator.cluster_centers_.transpose()[1].tolist()

import numpy as np
c1=list(np.int_(c1))
c2=list(np.int_(c2))

#for i in (0, estimator.n_clusters-1):
x0=x[estimator.labels_==0]
y0=y[estimator.labels_==0]
x1=x[estimator.labels_==1]
y1=y[estimator.labels_==1]
x2=x[estimator.labels_==2]
y2=y[estimator.labels_==2]

# %%
#Plot del conjunto original completo
fig = plt.figure()
plt.plot(x,y,'o')

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111)
ax1 = fig.add_subplot(111)
ax2 = fig.add_subplot(111)
axc = fig.add_subplot(111)

ax=ax.plot(x0,y0,'o')
ax1=ax1.plot(x1,y1,'o')
ax2=ax2.plot(x2,y2,'o')
axc=axc.plot(c1,c2,'o')

fig.show()
# Out:
# /home/zero/Apps/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# /home/zero/Apps/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:459: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
